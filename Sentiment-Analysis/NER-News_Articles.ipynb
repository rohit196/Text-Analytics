# %%
#Import Necessary Libraries
#%pip install lxml-html-clean newspaper3k
import spacy
from newspaper import Article
from spacy import displacy

# %%
# Download and load the spaCy model for English Language
#python -m spacy download en_core_web_sm


nlp = spacy.load("en_core_web_sm")

# %%
#Create Function to Extract Entities from Text
def extract_entities_from_url(url):
    #Download and prase the article
    article = Article(url)
    article.download()
    article.parse()

    #Extract the text from the article
    text = article.text

    # Apply NER using Spacy
    doc = nlp(text)

    # Extract and print the entities
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))
    
    return entities

# %%
#Example URL
url = "https://www.bbc.com/news/articles/cddyyyl4rm5o"

# %%
#Extract Entities
entities = extract_entities_from_url(url)

#Display the entitites 
for entity in entities:
    print(f"Entity: {entity[0]}, Label: {entity[1]}")
# Out:
# Entity: Indian, Label: NORP
# Entity: 6 hours ago, Label: TIME
# Entity: BBC News Share Save
#
# Courtesy, Label: ORG
# Entity: Savita, Label: ORG
# Entity: India, Label: GPE
# Entity: Sthal, Label: ORG
# Entity: 2023, Label: DATE
# Entity: India, Label: GPE
# Entity: first, Label: ORDINAL
# Entity: India, Label: GPE
# Entity: Friday, Label: DATE
# Entity: Maharashtra, Label: NORP
# Entity: Savita, Label: ORG
# Entity: Daulatrao Wandhare, Label: PERSON
# Entity: Jayant Digambar Somalkar, Label: PERSON
# Entity: Indian, Label: NORP
# Entity: Sthal, Label: PERSON
# Entity: first, Label: ORDINAL
# Entity: Nandini Chikte, Label: PERSON
# Entity: Savita, Label: PERSON
# Entity: two, Label: CARDINAL
# Entity: Savita, Label: PERSON
# Entity: Savita, Label: ORG
# Entity: Savita, Label: PERSON
# Entity: two-hour, Label: TIME
# Entity: Savita, Label: PERSON
# Entity: Savita, Label: PERSON
# Entity: fed, Label: ORG
# Entity: Savita, Label: PERSON
# Entity: one, Label: CARDINAL
# ...

# %%
#Create function to extract and visualiza the entities from text
def extract_entities_with_visual(url):
    #Download and prase the article
    article = Article(url)
    article.download()
    article.parse()

    #Extract the text from the article
    text = article.text

    # Apply NER using Spacy
    doc = nlp(text)

    # Extract and print the entities
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))

    #Visualize the entities
    displacy.render(doc, style="ent", jupyter=True)

    return entities

# %%
#Extract and Visualize Entities
entities = extract_entities_with_visual(url)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  film showing the bride's 'humiliation' in arranged marriage<br><br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 hours ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Share Save Geeta Pandey • @geetapandeybbc
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC News Share Save
#
# ...
